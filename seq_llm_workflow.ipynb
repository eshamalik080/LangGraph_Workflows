# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv
from groq import Groq

# %%
load_dotenv()  # Load environment variables from .env file
# Out:
# True

# %%
client = Groq()
models = client.models.list()

for model in models.data:
    print(model.id)
# Out:
# openai/gpt-oss-20b
# meta-llama/llama-prompt-guard-2-86m
# meta-llama/llama-prompt-guard-2-22m
# canopylabs/orpheus-arabic-saudi
# whisper-large-v3-turbo
# openai/gpt-oss-120b
# canopylabs/orpheus-v1-english
# qwen/qwen3.6-27b
# groq/compound-mini
# openai/gpt-oss-safeguard-20b
# groq/compound
# whisper-large-v3
# allam-2-7b
# qwen/qwen3.8-27b

# %%
model = ChatGroq(model="openai/gpt-oss-120b", temperature=0, max_tokens=1000)

# %%
#create state
class llmState(TypedDict):
    question: str
    answer: str

# %%
def llm_qa(state: llmState) -> llmState:

    #extract question from state
    question = state["question"]

    # form a prompt
    prompt = f"Answer the following question: {question}"

    #ask that question to llm
    answer = model.invoke(prompt).content

    # update the answer in state
    state["answer"] = answer

    return state

# %%
graph = StateGraph(llmState)

# add nodes
graph.add_node("llm_qa", llm_qa)

# add edges
graph.add_edge(START, "llm_qa")
graph.add_edge("llm_qa", END)

# compile
workflow = graph.compile()

# %%
# execute
initial_state = {"question": "what is turkey?"}

result = workflow.invoke(initial_state)

print(result["answer"])
# Out:
# **Turkey** can refer to two different things:
#
# | Meaning | Description |
# |---------|-------------|
# | **Bird** | The turkey (*Meleagris gallopavo*) is a large, domesticated bird native to North America. It’s known for its fleshy, dark meat and is a traditional centerpiece for Thanksgiving and other holiday meals in the United States and Canada. Wild turkeys also live in forests and grasslands across the continent. |
# | **Country** | The Republic of **Turkey** (Türkiye) is a transcontinental nation that straddles southeastern Europe and western Asia. Its capital is Ankara, its largest city is Istanbul, and it has a rich cultural heritage that blends ancient civilizations (like the Byzantine and Ottoman Empires) with modern, secular governance. |
#
# So, “turkey” can mean either the well‑known bird or the nation located at the crossroads of Europe and Asia.
